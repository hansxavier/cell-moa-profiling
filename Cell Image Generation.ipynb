# %%
import numpy as np
import pandas as pd
import os
import tqdm
from tqdm import tqdm

from PIL import Image

# %%
dirname = '/content/drive/MyDrive/CS 199/Cell Images/'

# %% [markdown]
# # Generate Cell Images

# %%
# Checks if metadata and compounds are in files
if not (any("BBBC021_v1_image.csv" in s for s in os.listdir(dirname)) and any("BBBC021_v1_moa.csv" in s for s in os.listdir(dirname))):
    raise ValueError("BBBC021_v1_image.csv and BBBC021_v1_moa.csv need to be in directory")

print("Found the files, starting the program to process the images.")
# the number of cropped images from the original image
crops = 4
# Out:
# Found the files, starting the program to process the images.

# %%
def slide_window(img, dims=(512, 640)):
    window_height, window_width = dims
    y, x = img.shape[:2]
    crop_images = np.zeros((4,512,640,3)) # dtype="uint8"

    index = 0
    col = 0
    for i in range(y//window_height):
        row = 0
        for j in range(x//window_width):
            crop_images[index] = img[row:row+window_height, col:col+window_width, :]
            row += window_height
            index += 1
        col += window_width
    return crop_images

# %%
def anscombe(x):
    x = x.astype(np.float32)
    return (2.0*np.sqrt(x + 3.0/8.0))

# %%
def DMSO_normalization(x,y,idx,crops,rm_imgs):
    '''
    Mean DMSO per plate per channel is subtracted from each [non-DMSO] image pixel-wise.
      input x is the transformed non-DMSO image
      input y is the transformed DMSO image
    the output is the non-DMSO image that has been normalized by DMSO statistics
    '''
    channels = x.shape[3]
    x = x.astype(np.float32)

    # Subtracting mean DMSO and divide std DMSO from/by non-DMSO images pixel-wise
    for i in range(channels):
        x[:,:,:,i] -= y[:,:,:,i].mean()
        x[:,:,:,i] /= y[:,:,:,i].std()

    # Map values to 8-bit integers and save to file
    # if crops = 4, slide_window function is used to generate cropped images.
    for i,j in zip(range(x.shape[0]), idx):

        # NewValue = (((OldValue - OldMin) * (NewMax - NewMin)) / (OldMax - OldMin)) + NewMin

        # Map to 8-bit int
        OldRange = (x[i,:,:,:].max() - x[i,:,:,:].min())
        NewRange = (255 - 0)
        xt = (((x[i,:,:,:] - x[i,:,:,:].min()) * NewRange) / OldRange) + 0
        imgs = slide_window(xt)
        for i,img in enumerate(imgs):
            if ((img > (NewRange/5.1)).sum()/img.size) <= 0.002:
                rm_imgs.append(i+j)

                continue
            img_cropped = Image.fromarray(img.astype("uint8"))
            # Save images to directory
            # img_cropped.save("images_bbbc021/bbbc021_%s.png" % str(j+i-len(rm_imgs)))

            # img_cropped.save("/content/drive/MyDrive/CS 199/Cell Images/updated pics/bbbc021_%s.png" % str(j+i-len(rm_imgs)))
            # TESTING SET FOR IMAGES
            img_cropped.save("/content/drive/MyDrive/CS 199/Cell Images/TRAINING SET/bbbc021_%s.png" % str(j+i-len(rm_imgs)))

    return

# %%
# read mechanism file
moa  = pd.read_csv(dirname+'/BBBC021_v1_moa.csv')
# read data file which link images to compound/concentration.
# which can then be linked to moa file
data = pd.read_csv(dirname+'/BBBC021_v1_image.csv')

# %%
labels = []
# keep track of images
count = 0
# keep track of dataset
dataset = 1
# List specifying images to be removed
rm_imgs = []

# %%
# Iterate through different directories (different plates)
for f in (f for f in os.listdir(dirname) if 'Week' in f):

  # Assign new variable for current plate
  plate_data = data[data['Image_PathName_DAPI'].str.contains(f)]

  idx = []
  plate_X = []
  plate_Y = []
  

  # Iterate through current plate
  for index, row in plate_data.iterrows():
      # Exclude all taxol compounds except certain examples from Week 1 plates
      if row['Image_Metadata_Compound'] == "taxol":
          if not (
                  'Week1_' in row['Image_PathName_DAPI']  and
                  'D0' in row['Image_Metadata_Well_DAPI'] and
                      (
                      "0.3" in str(row['Image_Metadata_Concentration']) or
                      "1.0" in str(row['Image_Metadata_Concentration']) or
                      "3.0" in str(row['Image_Metadata_Concentration'])
                      )
                  ):
              continue

      # Extract compounds that have a MOA annotation
      if moa[(moa['compound']      == row['Image_Metadata_Compound']) &
              (moa['concentration'] == row['Image_Metadata_Concentration'])].shape[0] > 0:

          try:
            #Read the images, skip if not found
            img_DAPI    = Image.open(dirname+'/%s/%s' % (f, row['Image_FileName_DAPI']))
            img_DAPI    = np.array(img_DAPI)

            img_Tubulin = Image.open(dirname+'/%s/%s' % (f, row['Image_FileName_Tubulin']))
            img_Tubulin = np.array(img_Tubulin)

            img_Actin   = Image.open(dirname+'/%s/%s' % (f, row['Image_FileName_Actin']))
            img_Actin   = np.array(img_Actin)
          except OSError as error:
            print(error)
            print(f + ": File not found!")
            continue
        

          # Make it RGB (stack the three channels) and append to list of images of current plate
          img_stack   = np.dstack((img_Actin, img_Tubulin, img_DAPI))
          plate_X.append(img_stack)

          # Obtain mechanism, compound and concentration for image
          mechanism  = moa[(moa['compound']      == row['Image_Metadata_Compound']) &
                          (moa['concentration'] == row['Image_Metadata_Concentration'])]

          # Append additional labels (apart from mechanism, compounds, concentrations) to labels list.
          # And all different rotations/mirrors (x 8).
          if row['Image_Metadata_Compound'] != 'DMSO':
              [labels.append([mechanism.values.tolist()[0][0],
                              mechanism.values.tolist()[0][1],
                              mechanism.values.tolist()[0][2],
                              row['Image_Metadata_Plate_DAPI'],
                              row['Image_Metadata_Well_DAPI'],
                              row['Replicate']]) for i in range(crops)]

              idx.append(count)
              count += crops

          plate_Y.append([mechanism.values.tolist()[0][0],
                          mechanism.values.tolist()[0][1],
                          mechanism.values.tolist()[0][2],
                          row['Image_Metadata_Plate_DAPI'],
                          row['Image_Metadata_Well_DAPI'],
                          row['Replicate']])


  plate_Y      = np.asarray(plate_Y)
  dmso_idx     = np.where(plate_Y[:,0] == "DMSO")[0]
  non_dmso_idx = np.where(plate_Y[:,0] != "DMSO")[0]

  if len(non_dmso_idx) > 0:
      plate_X = np.asarray(plate_X)
      plate_X = anscombe(plate_X)
      DMSO_normalization(plate_X[non_dmso_idx], plate_X[dmso_idx], idx, crops, rm_imgs)

  print('Number of compounds transformed = ' + str(count) + '; dataset = ' + str(dataset))
  dataset += 1
# Out:
# Number of compounds transformed = 208; dataset = 1
# Number of compounds transformed = 416; dataset = 2
# Number of compounds transformed = 512; dataset = 3
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_E07_s1_w193232854-973F-4689-B7CB-FB7038C59BDA.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_E07_s2_w1F1EF41B2-EA86-4AC5-8DB4-51D2A6E98F59.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_E07_s3_w160FE277B-535B-428E-A2EF-D9AEB4C4F86D.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_E07_s4_w1822D00C4-D980-412D-9020-F3CEBB36BF8E.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D06_s1_w19B2CBC81-98A8-41C5-90A2-291CA6A83D30.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D06_s2_w1D3CAD267-8B2D-4AE5-8FEC-3CE793AD39E8.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D06_s3_w1E5965534-D3F5-4DDE-A80F-0B6FD0611870.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D06_s4_w14D4DE3CD-FB1F-4B32-8028-925805AE595D.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D05_s1_w1AA3BF5F8-001D-4261-A369-4074B20091E1.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D05_s2_w16E829D32-0FB7-49FD-9826-1F63981A5384.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D05_s3_w129587FCD-B4B8-4779-B08D-6EEB22F0A764.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D05_s4_w123636619-1C7C-4144-ADC9-A292219A2CED.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D04_s3_w1941ED9BB-21A3-4D57-B8FD-774F93D61ED1.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D04_s4_w1D514EC40-44AD-46A0-B6FD-2864B616159D.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D04_s1_w173E7B462-19A6-4DE4-9B1D-9FBDED000356.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D04_s2_w15C608DDA-3CF3-4C65-B860-328EB5B9E980.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D02_s1_w194EE559B-B55A-476F-BF9F-BFF40B71868A.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D02_s2_w1698D12D5-FA38-4542-8F70-BD2F1B8DBB8C.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D02_s3_w19BC85FD3-9EE9-4C55-923D-C294D08DD56D.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_D02_s4_w1484180FE-1177-4340-8D27-789250039B13.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_E11_s1_w1DD8D28E7-3C97-4451-8BB7-6BFB6C8B1D5A.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_E11_s2_w1CC9DF329-E728-4DE3-95BF-6D87A85B835A.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_E11_s3_w16C01DAB0-ECD7-4C12-9F70-B2343F83F482.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_E11_s4_w150CF5478-3591-4837-A397-933B3457433E.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_F11_s1_w1E479FE88-06D2-4C30-A724-DA462161FB22.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_F11_s2_w1DE2748E0-C284-499F-A1E2-04E0AF684D50.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_F11_s3_w1FA240A05-AC0D-49B8-9B11-6AF319989EEE.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_F11_s4_w15AC0D400-FCB7-4075-869F-3300C06FD7F6.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_G11_s1_w16AACB3CC-D068-4E0F-B42A-40495262D0CF.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_G11_s2_w13CCF203A-A1C3-472D-BC96-E73CFFC99989.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_G11_s3_w146367E31-EFAB-4CD4-9412-17669A0945F3.tif'
# Week1_22381: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week1_22381/Week1_150607_G11_s4_w1C35738B4-7214-41BB-879F-58E35E514725.tif'
# Week1_22381: File not found!
# Number of compounds transformed = 544; dataset = 4
# Number of compounds transformed = 640; dataset = 5
# Number of compounds transformed = 704; dataset = 6
# Number of compounds transformed = 768; dataset = 7
# Number of compounds transformed = 800; dataset = 8
# Number of compounds transformed = 1008; dataset = 9
# Number of compounds transformed = 1040; dataset = 10
# Number of compounds transformed = 1072; dataset = 11
# Number of compounds transformed = 1392; dataset = 12
# Number of compounds transformed = 1712; dataset = 13
# Number of compounds transformed = 2032; dataset = 14
# Number of compounds transformed = 2176; dataset = 15
# Number of compounds transformed = 2320; dataset = 16
# Number of compounds transformed = 2464; dataset = 17
# Number of compounds transformed = 2496; dataset = 18
# Number of compounds transformed = 2528; dataset = 19
# Number of compounds transformed = 2560; dataset = 20
# Number of compounds transformed = 2720; dataset = 21
# Number of compounds transformed = 2880; dataset = 22
# Number of compounds transformed = 3040; dataset = 23
# Number of compounds transformed = 3088; dataset = 24
# Number of compounds transformed = 3136; dataset = 25
# Number of compounds transformed = 3184; dataset = 26
# Number of compounds transformed = 3184; dataset = 27
# Number of compounds transformed = 3184; dataset = 28
# Number of compounds transformed = 3184; dataset = 29
# Number of compounds transformed = 3200; dataset = 30
# Number of compounds transformed = 3200; dataset = 31
# Number of compounds transformed = 3216; dataset = 32
# Number of compounds transformed = 3232; dataset = 33
# Number of compounds transformed = 3232; dataset = 34
# Number of compounds transformed = 3232; dataset = 35
# Number of compounds transformed = 3312; dataset = 36
# Number of compounds transformed = 3392; dataset = 37
# Number of compounds transformed = 3472; dataset = 38
# Number of compounds transformed = 3552; dataset = 39
# Number of compounds transformed = 3632; dataset = 40
# Number of compounds transformed = 3680; dataset = 41
# Number of compounds transformed = 3728; dataset = 42
# Number of compounds transformed = 3776; dataset = 43
# Number of compounds transformed = 3808; dataset = 44
# Number of compounds transformed = 3840; dataset = 45
# Number of compounds transformed = 3888; dataset = 46
# Number of compounds transformed = 3936; dataset = 47
# Number of compounds transformed = 3984; dataset = 48
# Number of compounds transformed = 4096; dataset = 49
# Number of compounds transformed = 4208; dataset = 50
# Number of compounds transformed = 4320; dataset = 51
# Number of compounds transformed = 4448; dataset = 52
# Number of compounds transformed = 4576; dataset = 53
# Number of compounds transformed = 4704; dataset = 54
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_G03_s1_w14142C70E-0264-4429-BF84-E4CD4817EDAD.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_G03_s2_w123F98E97-BFEB-42DD-955E-B85840A755F1.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_G03_s3_w1A15B9766-CC14-4288-93FC-0BCBE8105241.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_G03_s4_w19C30C2DD-8A07-4DF2-AEF2-FF7A3D0234BD.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_E11_s1_w1F885D0CB-29FF-43CE-B0BE-CB44D3DE1009.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_E11_s2_w10378C179-D72D-4A2E-92FA-8314F886DC89.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_E11_s3_w16E01D8C0-DF4F-468E-9464-FD9D95E1B06B.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_E11_s4_w1DDE50CA9-AE1D-477F-AB5F-59D6F9932FBE.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_F11_s1_w1F6B939C8-9D61-44C5-B691-895DBEF067B2.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_F11_s2_w1478955DB-A2E3-43CC-A634-75706568CEC9.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_F11_s3_w143AEC449-6945-432C-A998-6B3991C76E7E.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_F11_s4_w164B2DEB2-B866-4277-AB83-C1CA98C5985E.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_G11_s1_w13B5ADBD0-CD53-41CE-B2E6-67C14E0BEBC3.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_G11_s2_w11B20AFDF-F1BF-403A-BDB1-69D041E61AC1.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_G11_s3_w15E24D811-0828-4EC9-89ED-807C101500B7.tif'
# Week2_24161: File not found!
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS 199/Cell Images//Week2_24161/Week2_180607_G11_s4_w1108BDE42-37E9-4FBA-884D-C37A7909A238.tif'
# Week2_24161: File not found!
# Number of compounds transformed = 4752; dataset = 55

# %%
print("Finished transforming compounds. Starting on adjusting the labels.")    
for index in sorted(rm_imgs, reverse=True):
    del labels[index]

df = pd.DataFrame(labels)
df.to_csv(dirname + '/TRAINING SET/bbbc021_labels.csv',
          header=["compound", "concentration", "moa", "plate", "well", "replicate"])

print("Finished adjusting labels. Image processing has finished.")
# Out:
# Finished transforming compounds. Starting on adjusting the labels.
# Finished adjusting labels. Image processing has finished.

# %%
folders = []
for f in (f for f in os.listdir(dirname) if 'Week' in f):
  folders.append(f)

folders_set = set(folders)


contains_duplicates = len(folders) != len(folders_set)



print(contains_duplicates)
# Out:
# False
